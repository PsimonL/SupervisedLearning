# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
print("Libs Loaded")

# %%
# Data source:
# http://onlinestatbook.com/2/case_studies/sat.html
data = pd.read_csv(r"high_school_sat_gpa.csv", sep=' ', usecols=['math_SAT','verb_SAT','high_GPA'])
data.head()
# Out:
#    high_GPA  math_SAT  verb_SAT
# 0      3.45       643       589
# 1      2.78       558       512
# 2      2.52       583       503
# 3      3.67       685       602
# 4      3.24       592       538

# %%
data.dtypes
# Out:
# high_GPA    float64
# math_SAT      int64
# verb_SAT      int64
# dtype: object

# %%
data.plot.scatter("math_SAT", "high_GPA", 20, "red")
# plt.scatter(data["math_SAT"], data["high_GPA"], color='red')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 3>()
#       1 data.plot.scatter("math_SAT", "high_GPA", 20, "red")
#       2 # plt.scatter(data["math_SAT"], data["high_GPA"], color='red')
# ----> 3 data.plot.show()
#
# AttributeError: 'PlotAccessor' object has no attribute 'show'

# %%
X = data["math_SAT"]
X
# Out:
# 0      643
# 1      558
# 2      583
# 3      685
# 4      592
#       ...
# 100    605
# 101    692
# 102    680
# 103    617
# 104    516
# Name: math_SAT, Length: 105, dtype: int64

# %%
y = data["high_GPA"]
y
# Out:
# 0      3.45
# 1      2.78
# 2      2.52
# 3      3.67
# 4      3.24
#        ...
# 100    3.76
# 101    3.49
# 102    3.07
# 103    2.19
# 104    3.46
# Name: high_GPA, Length: 105, dtype: float64

# %%
XVal = X.values
yVal = y.values
XVal
# Out:
# array([643, 558, 583, 685, 592, 562, 573, 559, 552, 617, 684, 568, 604,
#        619, 642, 683, 703, 712, 564, 557, 591, 599, 607, 619, 700, 718,
#        580, 562, 683, 717, 701, 691, 714, 689, 554, 564, 668, 691, 573,
#        568, 607, 651, 604, 560, 604, 574, 564, 607, 619, 647, 651, 571,
#        583, 554, 568, 574, 605, 591, 642, 608, 574, 643, 608, 709, 691,
#        667, 656, 554, 692, 684, 717, 712, 641, 675, 692, 684, 564, 554,
#        685, 671, 571, 582, 621, 651, 673, 651, 672, 591, 582, 609, 554,
#        612, 628, 567, 619, 691, 564, 650, 551, 568, 605, 692, 680, 617,
#        516], dtype=int64)

# %%
XVal.reshape(-1, 1)
# Out:
# array([[643],
#        [558],
#        [583],
#        [685],
#        [592],
#        [562],
#        [573],
#        [559],
#        [552],
#        [617],
#        [684],
#        [568],
#        [604],
#        [619],
#        [642],
#        [683],
#        [703],
#        [712],
#        [564],
#        [557],
#        [591],
#        [599],
#        [607],
#        [619],
#        [700],
#        [718],
#        [580],
#        [562],
#        [683],
#        [717],
#        [701],
#        [691],
#        [714],
#        [689],
#        [554],
#        [564],
#        [668],
#        [691],
#        [573],
#        [568],
#        [607],
#        [651],
#        [604],
#        [560],
#        [604],
#        [574],
#        [564],
#        [607],
#        [619],
#        [647],
#        [651],
#        [571],
#        [583],
#        [554],
#        [568],
#        [574],
#        [605],
#        [591],
#        [642],
#        [608],
#        [574],
#        [643],
#        [608],
#        [709],
#        [691],
#        [667],
#        [656],
#        [554],
#        [692],
#        [684],
#        [717],
#        [712],
#        [641],
#        [675],
#        [692],
#        [684],
#        [564],
#        [554],
#        [685],
#        [671],
#        [571],
#        [582],
#        [621],
#        [651],
#        [673],
#        [651],
#        [672],
#        [591],
#        [582],
#        [609],
#        [554],
#        [612],
#        [628],
#        [567],
#        [619],
#        [691],
#        [564],
#        [650],
#        [551],
#        [568],
#        [605],
#        [692],
#        [680],
#        [617],
#        [516]], dtype=int64)

# %%
LR_math = LinearRegression()
LR_math.fit(XVal.reshape(-1, 1), yVal.reshape(-1, 1))
# Out:
# LinearRegression()

# %%
x_min = data["math_SAT"].min()
x_min
# Out:
# 516

# %%
x_max = data["math_SAT"].max()
x_max
# Out:
# 718

# %%
#plt.figure(figsize=(, )) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html
data.plot.scatter("math_SAT", "high_GPA", 20, "red")
# data.plot(X, LinearRegression(), color="blue", label="Linear Regression")
plt.plot([x_min, x_max], LR_math.predict([[x_min],[x_max]]), color="blue", label="Linear Regression")
